# %% [markdown]
# # Part - I : Crawling Twitter

# %% [markdown]
# ### Import statements

# %%
import jsonlines
import tweepy
from tweepy import OAuthHandler

# %% [markdown]
# ### Authentication Keys

# %%
# Replace with original keys for successful authentication

c_key = '******'
c_secret = '******'
a_token = '******'
a_secret = '******'

# %% [markdown]
# ### Function to authorize access

# %% [markdown]
# <b>Parameters:</b> c_key (Consumer Key), c_secret (Consumer Secret), a_token (Access Token), a_secret (Access Token Secret) <br>
# <b>Return Value:</b> api => api object which provides access to Twitter content

# %%
def authUser(c_key, c_secret, a_token, a_secret):
    auth = OAuthHandler(c_key, c_secret)
    auth.set_access_token(a_token, a_secret)
    api = tweepy.API(auth)
    return api

# %% [markdown]
# ### Function to write each tweet into a .jsonl file

# %% [markdown]
# <b>Parameters:</b> tweet_dict => a tweet in the form of a dictionary <br>
# <b>Return Value:</b> total_tweets => Total number of tweets by the user (useful in loop termination while crawling)

# %%
def storeTweet(tweet_dict):
    with jsonlines.open('responses.jsonl', mode='a') as writer:
        writer.write(tweet_dict)
    total_tweets = tweet_dict['user']['statuses_count']
    return total_tweets

# %% [markdown]
# ### Function to retrieve tweets and store them in .jsonl file

# %% [markdown]
# <b>Parameters:</b> api => object to access Twitter content, s_name => screen name, maxid => id of the last tweet fetched  <br>
# <b>Return Value:</b> maxid => id of the latest fetched tweet, total_tweets => total number of tweets by the user, loc_counter => number of fetched tweets written to 'responses.jsonl'

# %% [markdown]
# <div style="text-align: justify"> <b>Explanation:</b> The following function retrieves 200 tweets at a time and stores them in an 'Iterable' list which is traversed using the for loop. The '._json' attribute is used to access the JSON response sent by the Twitter API. Variable 'maxid' is used to keep track of the latest tweet id that has been fetched so that duplicate tweets are not picked up each time the script is made to run. Variable 'total_tweets' stores the total count of user's tweets. 'loc_counter' is used to keep track of the number of updates in 'responses.jsonl' file. </div>

# %%
def fetchNStore(api, s_name, maxid):
    loc_counter = 0
    total_tweets = 0
    if maxid is None:
        for tweet in tweepy.Cursor(api.user_timeline, screen_name=s_name, tweet_mode='extended').items(200):
            total_tweets = storeTweet(tweet._json)
            maxid = int(tweet._json['id']) - 1
            loc_counter += 1
    else:
        for tweet in tweepy.Cursor(api.user_timeline, screen_name=s_name, tweet_mode='extended', max_id=maxid).items(200):
            total_tweets = storeTweet(tweet._json)
            maxid = int(tweet._json['id']) - 1
            loc_counter += 1
    return maxid, total_tweets, loc_counter

# %% [markdown]
# ### Script to call the above-defined functions

# %% [markdown]
# <div style="text-align: justify"> <b>Explanation:</b> 'lastfetched.txt' stores the latest id of the fetched tweet. Keeping track of this id is important as it avoids writing of duplicate tweets to 'responses.jsonl'. This functionality is helpful in cases where the rate limits (imposed by Twitter API) exceed while fetching of data. The 'while' loop runs till the total number of tweets have been written to 'responses.jsonl'. 'try-except' mechanism is used to look out for rate-limit exceed errors or any other errors caused while fetching of data. 'totalfetched.txt' keeps track of the total number of tweets written so far into 'responses.jsonl'. This is useful when we want to resume fetching of tweets from a particular point in case of any interruptions that might have occurred earlier. </div>

# %%
screen_name = 'midasIIITD'
api = authUser(c_key, c_secret, a_token, a_secret)
# fobj = open('lastfetched.txt', 'w')              # uncomment both lines if 'lastfetched.txt' does not exist
# fobj.close()
with open('lastfetched.txt', 'r') as reader:
    maxid = reader.readline()
if maxid == "":
    maxid = None
else:
    maxid = int(maxid)
try:
    flag = True
    try:
        with open('totalfetched.txt', 'r') as r:
            glob_counter = int(r.readline())         # updating glob_counter to the number of tweets already read
    except FileNotFoundError:
        glob_counter = 0
    total_tweets = 0
    while flag:
        maxid, new_tweet_count, loc_counter = fetchNStore(api, screen_name, maxid)
        total_tweets = new_tweet_count
        with open('lastfetched.txt', 'w') as writer:
            writer.write(str(maxid))
        glob_counter += loc_counter
        if glob_counter >= new_tweet_count:          # value of total_tweets obtained dynamically allows for loop termination
            flag = False
    print('All tweets (%d) extracted from %s.' % (total_tweets, screen_name))
except Exception as error:
    with open('totalfetched.txt', 'w') as w:          # writing the total number of tweets seen so far
        w.write(str(glob_counter))
    print(error)
# Out:
# All tweets (296) extracted from midasIIITD.

# %% [markdown]
# # Part - II : Parsing JSON Files

# %% [markdown]
# ### Import statements

# %%
import prettytable
from datetime import datetime

# %% [markdown]
# ### Function which parses the .jsonl file and arranges content in a table

# %% [markdown]
# <b>Parameters:</b> file_name => file to be parsed  <br>
# <b>Return Value:</b> table => object of class PrettyTable which contains data arranged in tabular format.

# %% [markdown]
# <b> Assumption: </b> The number of favourites/likes, retweets and images present are to be reported of the original tweet and not of the tweet that has been retweeted.

# %%
def createTable(file_name):
    table = prettytable.PrettyTable()
    table.add_column('S.No', [])
    table.add_column('Text', [])
    table.add_column('Date-Time', [])
    table.add_column('# of likes', [])
    table.add_column('# of retweets', [])
    table.add_column('# of images present', [])
    with jsonlines.open(file_name) as reader:
        index = 0
        for tweet in reader:
            image_count = None
            text = tweet['full_text']             # full_text used to include tweets of length upto 280 characters
            raw_dt = tweet['created_at']
            date_time = datetime.strptime(raw_dt, "%a %b %d %H:%M:%S %z %Y").strftime("%d/%m/%Y %H:%M:%S")
            likes = tweet['favorite_count']
            retweets = tweet['retweet_count']
            ent = tweet['entities']
            if ent.get('media') is not None:
                image_count = 0
                ext_ent = tweet['extended_entities']
                lst = ext_ent['media']
                for i in range(len(lst)):
                    if lst[i]['type'] == 'photo':
                        image_count += 1 
            index += 1
            table.add_row([index, text, date_time, likes, retweets, image_count])
    return table

# %% [markdown]
# ### Script to call the above function and print the table

# %%
table = createTable('responses.jsonl')
print(table)
# Out:
# +------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+------------+---------------+---------------------+
# | S.No |                                                                                                                                                       Text                                                                                                                                                       |      Date-Time      | # of likes | # of retweets | # of images present |
# +------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+------------+---------------+---------------------+
# |  1   |                                                                                                                                 @IEEEBigMM19 is also available on Facebook now.                                                                                                                                  | 20/03/2019 08:19:24 |     1      |       1       |         None        |
# |      |                                                                                                                   LIKE its Facebook page https://t.co/B3Q0zmmzXb  to get the regular updates.                                                                                                                    |                     |            |               |                     |
# |      |                                                                                                                                  Check more details at https://t.co/w9ZymoPisk                                                                                                                                   |                     |            |               |                     |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                                    #IEEE #BigMM19 #Big #Multimedia #Singapore                                                                                                                                    |                     |            |               |                     |
# |  2   |                                                                                                                  RT @IEEEBigMM19: BigMM 2019 : IEEE BigMM 2019 – Call for Workshop Proposals                                                                                                                     | 20/03/2019 02:40:07 |     0      |       4       |         None        |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                                           https://t.co/I4vqf8FE6K …                                                                                                                                              |                     |            |               |                     |
# |      |                                                                                                                                        When: Sep 11, 2019 - Sep 13, 201…                                                                                                                                         |                     |            |               |                     |
# |  3   |                                                                                                                            BigMM 2019 : IEEE BigMM 2019 – Call for Workshop Proposals                                                                                                                            | 18/03/2019 02:27:47 |     6      |       3       |         None        |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                                             https://t.co/oUq2G0UgKN                                                                                                                                              |                     |            |               |                     |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                                        When: Sep 11, 2019 - Sep 13, 2019                                                                                                                                         |                     |            |               |                     |
# |      |                                                                                                                                                 Where: Singapore                                                                                                                                                 |                     |            |               |                     |
# |      |                                                                                                                                         Submission Deadline: Apr 1, 2019                                                                                                                                         |                     |            |               |                     |
# |      |                                                                                                                                          Notification Due: Apr 10, 2019                                                                                                                                          |                     |            |               |                     |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                             #IEEE #BigMM #Workshop #Proposal #Singapore #Multimedia                                                                                                                              |                     |            |               |                     |
# |  4   |                Congratulations @midasIIITD team, Rohan, Pradyumn, Ramit, @debanjanbhucs, @MADAIguy and @RatnRajiv for getting their paper titled, "SNAP-BATNET: Cascading Author Profiling and Social Network Graphs for Suicide Ideation Detection on Social Media", accepted at @NAACLHLT SRW.                 | 17/03/2019 14:22:04 |     15     |       4       |         None        |
# |  5   |                                                                                                We have emailed the task details to all shortlisted candidates for @midasIIITD internship. Kindly check the same.                                                                                                 | 16/03/2019 14:06:56 |     6      |       0       |         None        |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                           If you are one of the shortlisted candidates and have not received the email then check your SPAM first before approaching.                                                                                            |                     |            |               |                     |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                                       #MIDAS #Summer #Research #Internship                                                                                                                                       |                     |            |               |                     |
# |  6   |                                                                                                                                 IEEE BigMM 2019 - Call for Workshop Proposals.                                                                                                                                   | 16/03/2019 09:20:29 |     1      |       1       |         None        |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                      Contact @midasIIITD @RatnRajiv @debanjanbhucs if you have any query.                                                                                                                        |                     |            |               |                     |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                                                   Deadlines:                                                                                                                                                     |                     |            |               |                     |
# |      |                                                                                                                                          - Proposals due: April 1, 2019                                                                                                                                          |                     |            |               |                     |
# |      |                                                                                                                                    - Acceptance notification: April 10, 2019                                                                                                                                     |                     |            |               |                     |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                                               Further information:                                                                                                                                               |                     |            |               |                     |
# |      |                                                                                                                                        - Webpage: https://t.co/5XX5Wyxp5T                                                                                                                                        |                     |            |               |                     |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                                                  #IEEE #BigMM19                                                                                                                                                  |                     |            |               |                     |
# |  7   |                                                            Congratulations! Arijit, Ramit, @debanjanbhucs @RatnRajiv for your @NAACLHLT  @naacl SRW 2019 paper, "Speak Up, Fight Back! Detection of Social Media Disclosures of Sexual Harassment".                                                              | 16/03/2019 09:14:58 |     7      |       2       |         None        |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                                  Check more details at https://t.co/i6eAHg7gcN                                                                                                                                   |                     |            |               |                     |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                                     #MeToo #Student #Research  #Paper #NAACL                                                                                                                                     |                     |            |               |                     |
# |  8   |              We will be releasing a very interesting task to shortlisted candidates for the internship at @midasIIITD today. You will be having 10 days to solve the same. You will get a detailed email on the task and submission instruction today. Looking forward to your out of box solution.              | 16/03/2019 05:13:14 |     7      |       2       |         None        |
# |  9   |                                                                                   RT @hcdiiitd: Last day to register for #PortfolioCreationinDesign Workshop Indraprastha Institute of Information Technology, Delhi on 15th…                                                                                    | 13/03/2019 17:09:44 |     0      |       2       |         None        |
# |  10  |                                                                                                      @ACMMM19 @sigmm @TheOfficialACM @acmmmsys @ACMTVX @ACMICMR @euromm @Benoit_Huet @RatnRajiv @kelkalot                                                                                                        | 13/03/2019 04:11:24 |     1      |       0       |          1          |
# |      |                                                                                                          We need to clearly mention abstract and final submission deadlines at https://t.co/U7DTNNyw87                                                                                                           |                     |            |               |                     |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                      Currently, we have just mentioned 1st April as the regular paper submission deadline. Kindly update.                                                                                                        |                     |            |               |                     |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                                #ACMMM19 #Nice #Multimedia https://t.co/ocOCrlFHLH                                                                                                                                |                     |            |               |                     |
# |  11  |                                                                                   RT @ACMMM19: The paper deadline is approaching. 1 April abstract is due. Authors will have until 8 April to upload the final PDF version of…                                                                                   | 13/03/2019 04:06:04 |     0      |       13      |         None        |
# |  12  |                                                                                   RT @kaggle: Bookmark this amazing library of image augmentations 😵 by #Kaggle Masters @AlBuslaev @creaf @viglovikov and @cvtalks | https://…                                                                                   | 12/03/2019 17:43:44 |     0      |       69      |         None        |
# |  13  |                                                                                                  Awesome members of our @midasIIITD team who are working on Humonics projects. Great to have you on our team.                                                                                                    | 12/03/2019 14:37:55 |     16     |       4       |          1          |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                            #team #research #AI #ML #projects https://t.co/lN7hItwPO9                                                                                                                             |                     |            |               |                     |
# |  14  |                                                                                                                                  @saanidhi @ACMMM19 Before Friday, 15th March.                                                                                                                                   | 11/03/2019 14:58:30 |     0      |       0       |         None        |
# |  15  |                                                                                We are glad to inform that Adobe is launching Women’s day Tech-Challenge to hire female engineers from 2019 Batch under our #SheCodes initiative.                                                                                 | 11/03/2019 12:02:42 |     4      |       0       |         None        |
# |      |                                                                                                                Please register here for participating in the challenge at https://t.co/DjkKCJHDBC                                                                                                                |                     |            |               |                     |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                                  Check full details at https://t.co/5ArLu3icva                                                                                                                                   |                     |            |               |                     |
# |  16  |                                                     We will email tasks to all shortlisted candidates for an internship at @midasIIITD by Friday, 15th March. If you are shortlisted and did not hear from us by that time then kindly drop an email to us.                                                      | 11/03/2019 11:54:38 |     3      |       0       |         None        |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                                       Looking forward to working with you.                                                                                                                                       |                     |            |               |                     |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                                        #research #Internship #AI @ACMMM19                                                                                                                                        |                     |            |               |                     |
# |  17  |                                                                                                        @ACMMM19 @ACM_MM2018 @acmmm17 @sigmm @ACM Less than three weeks are left for @ACMMM19 submission.                                                                                                         | 11/03/2019 06:22:12 |     1      |       1       |         None        |
# |      |                                                                                                                   Looking forward to your contribution to #ACMMM and see you in Nice, France.                                                                                                                    |                     |            |               |                     |
# |      |                                                                                @midasIIITD @iiit_hyderabad @iitdelhi @abhinavdhall @iitmadras @iiscbangalore @IITKanpur @iitbombay @iitkharagpur @IITJodhpur @iitropar @IIITDelhi                                                                                |                     |            |               |                     |
# |  18  |                                                                                                                     RT @kdnuggets: Face Recognition using One-Shot Learning – #DeepLearning                                                                                                                      | 11/03/2019 06:17:20 |     0      |       64      |         None        |
# |      |                                                                                                                       using DL architecture that works great with one-shot learning calle…                                                                                                                       |                     |            |               |                     |
# |  19  |                                                                                              @AvinashSwamina2 @IIITDelhi No. They will be given tasks along with students who will be selected in the second round.                                                                                              | 08/03/2019 13:22:07 |     1      |       0       |         None        |
# |  20  |                                                                                     We are in the process of finalizing the shortlisted candidates for internship at @midasIIITD which we have received in the second round.                                                                                     | 08/03/2019 13:15:34 |     8      |       4       |         None        |
# |      |                                                                                  We will assign tasks to all shortlisted candidates around early next week. We are also delaying the task since DTU has mid-sem until 15 March.                                                                                  |                     |            |               |                     |
# |  21  |                                                                                                                        @ylecun @NilayShri @the_dhumketu @debanjanbhucs will it be useful?                                                                                                                        | 06/03/2019 13:44:11 |     3      |       0       |         None        |
# |  22  |                                                                                                         RT @kdnuggets: Python Data Science for Beginners https://t.co/yRExdmdZGh https://t.co/vRqTRuayO3                                                                                                         | 06/03/2019 11:12:30 |     0      |       22      |          1          |
# |  23  |                                                                                 RT @stanfordnlp: Useful feature of our Python stanfordnlp: get lemmas &amp; morphology in many languages. Le ski de fond touché→lemma toucher f…                                                                                 | 03/03/2019 19:36:04 |     0      |       35      |         None        |
# |  24  |                                                                                                             @NilayShri @NilayShri, Certain thing! The next team outing will be for lipreading team.                                                                                                              | 03/03/2019 17:09:48 |     1      |       0       |         None        |
# |      |                                                                                                                                    Probably, just after @ACMMM19 submission.                                                                                                                                     |                     |            |               |                     |
# |  25  |                                                                                                                            At @midasIIITD, we not only work hard but also have fun.                                                                                                                              | 03/03/2019 15:37:28 |     9      |       1       |          3          |
# |      |                                                                                           Today, we had a team (for Humonics sponsored projects) outing at Pirates of Grill. It was a wonderful day with lots of fun.                                                                                            |                     |            |               |                     |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                                    #fun #lunch #MIDAS https://t.co/MEVA1NfHRd                                                                                                                                    |                     |            |               |                     |
# |  26  |                           Considering several requests to extend the deadline for internship application, @midasIIITD at @IIITDelhi has decided that we will open the internship form https://t.co/t54AZ9eo26 again on March 7 and process all application received by March 8, 10 am.                           | 03/03/2019 14:55:31 |     6      |       2       |         None        |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                                            #research #Internship #AI                                                                                                                                             |                     |            |               |                     |
# |  27  |                                                                                                               RT @jeremyphoward: 39 studies about human perception in 30 minutes by @kennelliott                                                                                                                 | 03/03/2019 14:26:40 |     0      |      315      |         None        |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                             Awesome article. If you do any visualization or comput…                                                                                                                              |                     |            |               |                     |
# |  28  |                                                                                                                                     Correction:   @midasIIITD at @IIITDelhi                                                                                                                                      | 02/03/2019 17:43:05 |     1      |       0       |         None        |
# |  29  |             Thanks much to all aspirants who have applied for the summer internship 2019 at @midasIIITD at @midasIIITD. We have received over 200 applications. Thus, many good applications are not selected for next round. We have sent emails to all candidates, kindly check that for results.              | 02/03/2019 09:59:03 |     7      |       1       |         None        |
# |  30  |                                                                                             RT @kdnuggets: Keras Hyperparameter Tuning in Google Colab Using Hyperas https://t.co/hmaI4ukJRX https://t.co/s3nTqqgnAb                                                                                             | 28/02/2019 14:21:21 |     0      |       4       |          1          |
# |  31  |                                                                                                                    RT @RatnRajiv: Great meeting with @midasIIITD alumnus, Sanket Jain today.                                                                                                                     | 26/02/2019 18:30:52 |     0      |       1       |         None        |
# |      |                                                                                                                        He was among first MTech students who worked with me at @IIITDelh…                                                                                                                        |                     |            |               |                     |
# |  32  |                                                                                                                            Correction: They have published the following paper only:                                                                                                                             | 26/02/2019 03:40:22 |     0      |       0       |         None        |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                  PROMPT: Personalized User Tag Recommendation for Social Media Photos Leveraging Personal and Social Contexts.                                                                                                   |                     |            |               |                     |
# |  33  |                                                                                                  We will process all applications received by March 1, 2019 and notify all shortlisted candidates by March 3.                                                                                                    | 25/02/2019 16:10:46 |     2      |       1       |         None        |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                              If you have not applied yet for @midasIIITD internship then you may do so by filling the form https://t.co/t54AZ9eo26                                                                                               |                     |            |               |                     |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                                  #MIDAS #IIITD #Internship #NLP #ML #AI #DL #CV                                                                                                                                  |                     |            |               |                     |
# |  34  |                                                                                   RT @ecsquendor: Jit Ghosh discusses the "GloVe" 2014 Stanford paper on word embeddings. This one was a great session! #paperreviewcalls #nl…                                                                                   | 24/02/2019 03:39:40 |     0      |       8       |         None        |
# |  35  |                                                                                   RT @goodfellow_ian: This CVPR workshop is looking for applications of computer vision in developing countries. You don't need to submit a f…                                                                                   | 23/02/2019 15:41:27 |     0      |       90      |         None        |
# |  36  |                                                                                                                                  RT @IIITDelhi: PhD Admission 2019 are open now                                                                                                                                  | 22/02/2019 11:54:49 |     0      |       8       |         None        |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                           Online applications starts from 20th February 2019 and the last date to apply is 14th March…                                                                                                           |                     |            |               |                     |
# |  37  |                                                                                                RT @kdnuggets: #AI for Social Good study - how to inform policy, achieve interpretability, reduce bias and more -                                                                                                 | 21/02/2019 16:27:54 |     0      |       14      |         None        |
# |      |                                                                                                                                            include review of global…                                                                                                                                             |                     |            |               |                     |
# |  38  |                                                                                                                       @IIITDelhi has initiated PhD Admission 2019 process (Regular Round).                                                                                                                       | 21/02/2019 06:39:27 |     2      |       1       |         None        |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                         Online applications start from 20th February 2019 and the last date to apply is 14th March 2019.                                                                                                         |                     |            |               |                     |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                    For more details please visit the following link: https://t.co/qWa9I7CFqX.                                                                                                                    |                     |            |               |                     |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                                              #IIITD #PhD #Admission                                                                                                                                              |                     |            |               |                     |
# |  39  |                                                                                   RT @radamihalcea: We tend to focus mainly on creating learning algorithms, and yet there is so much that can be gained from unlearning. In…                                                                                    | 21/02/2019 04:48:24 |     0      |       13      |         None        |
# |  40  |                                                                                                                       @RealAAAI @RatnRajiv Thanks, @RealAAAI for recognizing our efforts.                                                                                                                        | 20/02/2019 07:09:19 |     4      |       2       |          1          |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                         Congratulations, @midasIIITD students for winning Best Student Poster award at 33rd AAAI Conference on Artificial Intelligence.                                                                                          |                     |            |               |                     |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# ...
# | 270  |                                                                                   RT @IIITDelhi: @midasIIITD has secured rank 1 in the IRMiDis challenge of the 10th FIRE 2018 conference. Congratulations MIDAS interns, Sak…                                                                                   | 08/08/2018 05:45:58 |     0      |       1       |         None        |
# | 271  |                                                                                                     RT @kdnuggets: Comparison of Top 6 Python NLP Libraries https://t.co/3ubomIUh4N https://t.co/KgP6R9mZsD                                                                                                      | 07/08/2018 07:16:33 |     0      |       40      |          1          |
# | 272  |                                                                                              Check more details of the 20th IEEE International Symposium on Multimedia (ISM) conference at https://t.co/wMIaXBfCYR.                                                                                              | 07/08/2018 02:05:12 |     1      |       1       |         None        |
# |      |                                                                               It is an international forum for researchers to exchange information regarding advances in the state of the art and practice of multimedia computing.                                                                              |                     |            |               |                     |
# |      |                                                                                                                                                     #MR2AMC                                                                                                                                                      |                     |            |               |                     |
# | 273  |                                 MR2AMC@ISM 2018 will be organized by @RatnRajiv (@midasIIITD), @debanjanbhucs (@TechAtBloomberg), Yifang Yin (@NUSComputing), and @soujanyaporia (@NTUsg). Thanks to Prof Roger Zimmermann (NUS) for being the honorary chair for the workshop.                                  | 07/08/2018 01:58:49 |     1      |       1       |         None        |
# |      |                                                                                                                                       #ISM2018 #IEEE #MIDAS @IIITDelhi 2/2                                                                                                                                       |                     |            |               |                     |
# | 274  |                                                                                                                         Our workshop proposal named, "MR2AMC: Multimodal Representation,                                                                                                                         | 07/08/2018 01:50:33 |     1      |       1       |         None        |
# |      |                                                        Retrieval, and Analysis of Multimedia Content in Social Media", has been accepted to the 20th IEEE International Symposium on Multimedia (ISM) conference. Looking forward to your contributions.                                                         |                     |            |               |                     |
# |      |                                                                                                                                               #MIDAS #ISM2018  1/2                                                                                                                                               |                     |            |               |                     |
# | 275  |                                                                                                                           @NUSComputing Congratulations Abdelhak and Prof Zimmermann.                                                                                                                            | 06/08/2018 17:48:23 |     0      |       0       |         None        |
# | 276  |                                                                                           RT @goodfellow_ian: One of the most anticipated GAN names now taken: paGAN. https://t.co/ifUgy40O8t https://t.co/NvxKDwEMZz                                                                                            | 06/08/2018 17:46:59 |     0      |      103      |          1          |
# | 277  |                                                                                                                                  @the_dhumketu Great to have you in @midasIIITD                                                                                                                                  | 06/08/2018 06:06:47 |     0      |       0       |         None        |
# | 278  |                   Congratulation @soujanyaporia for being appointed as an Adjunct Faculty of @IIITDelhi. He will be working with team @midasIIITD in collaboration with Prof @RatnRajiv on several interesting projects. Welcome to MIDAS and IIITD family. #NTU #IIITD #MIDAS #Collaboration                    | 03/08/2018 05:56:33 |     6      |       1       |         None        |
# | 279  |                                                                                                                     @IIITDelhi @the_dhumketu Thanks team @midasIIITD https://t.co/2WvhaHBq3h                                                                                                                     | 01/08/2018 11:47:15 |     5      |       1       |          1          |
# | 280  |                                                                                   RT @IIITDelhi: Congratulations @midasIIITD intern @the_dhumketu for getting his paper titled,"Harnessing AI for Speech Reconstruction using…                                                                                   | 01/08/2018 11:20:07 |     0      |       4       |         None        |
# | 281  |                                                                                                           RT @learning_pt: Profile of the 5 Indian undergrads admitted to MIT for 2018-2022 session.                                                                                                             | 01/08/2018 05:06:47 |     0      |       4       |         None        |
# |      |                                                                                                                                 Note, how they grabbed the Linguistics Olympiad…                                                                                                                                 |                     |            |               |                     |
# | 282  |                                                                                 Have a look at the list of accepted papers in ACM Multimedia 2018 if you are willing to work on some interesting multimedia research problems.                                                                                   | 31/07/2018 12:11:52 |     1      |       0       |         None        |
# |      |                                                                                                                                             https://t.co/TEPg200yB6                                                                                                                                              |                     |            |               |                     |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                                                                 #MIDAS #ACMMultimedia2018 #ACM #MultimediaResearch #Multimedia #IIITD #NUS #NII                                                                                                                  |                     |            |               |                     |
# | 283  |                                                                                   RT @goodfellow_ian: https://t.co/hYiWI7ntyk TensorFuzz automates the process of finding inputs that cause some specific testable behavior,…                                                                                    | 31/07/2018 02:06:26 |     0      |      264      |         None        |
# | 284  |                                                                                   RT @IIITDelhi: Congratulations Dr. @RatnRajiv and team @midasIIITD for getting their paper titled,"Learning and Fusing Multimodal Deep Feat…                                                                                   | 30/07/2018 07:30:51 |     0      |       2       |         None        |
# | 285  |                                                                                   RT @ylecun: Jitendra Malik, who directs FAIR-Menlo Park, talks about the future of computer vision in his acceptance talk after receiving t…                                                                                   | 28/07/2018 11:07:11 |     0      |       57      |         None        |
# | 286  |                                                                                   RT @kdnuggets: .@Bloomberg launches free course  "Foundations of #MachineLearning" for those with Strong #Math Backgrounds  https://t.co/9R…                                                                                   | 28/07/2018 06:14:09 |     0      |      105      |         None        |
# | 287  |                                                                                           RT @TechAtBloomberg: Missed #PyLondinium18? Watch the videos of the keynotes and other speakers now: https://t.co/ZdsCV6csy7                                                                                           | 28/07/2018 06:13:48 |     0      |       7       |         None        |
# | 288  |                                                                                   RT @IIITDelhi: We are delighted to announce that @IIITDelhi has joined hands with University at Buffalo, the State University of New York f…                                                                                   | 28/07/2018 04:08:21 |     0      |       6       |         None        |
# | 289  |                                               Get ready for the annual technical fest of @IIITDelhi, Esya, on 17th and 18th August 2018. The theme for this year's edition is Technology for Social Change and all the events will be incorporated with the same.                                                | 27/07/2018 06:46:44 |     3      |       2       |         None        |
# |      |                                                                                                                        Check more details at https://t.co/kpINK6bfU5 #ESYA #MIDAS #IIITD                                                                                                                         |                     |            |               |                     |
# | 290  |             Congratulations Dr. @RatnRajiv and team @midasIIITD for getting their paper titled,"Learning and Fusing Multimodal Deep Features for Acoustic Scene Categorization" accepted in ACM Multimedia 2018, a top-tier conference for multimedia. Visit https://t.co/pEMPKivWvO to join MIDAS.              | 27/07/2018 04:07:31 |     8      |       2       |         None        |
# | 291  |                    Congratulations MIDAS @midasIIITD intern Prakhar Srivastava @prakharcode for being selected to give a talk in PyCon Poland @pyconpl and PyCon France @pyconfr. #MIDAS #Congratulations #PyCon #IIITD #Python #NUS #NII @pycon @IIITDelhi  @TechAtBloomberg @debanjanbhucs                     | 25/07/2018 05:14:35 |     5      |       1       |         None        |
# | 292  |                                                                                                                                 MIDAS@IIITD foundation. https://t.co/LKuzyBHzjm                                                                                                                                  | 24/07/2018 10:33:23 |     2      |       1       |         None        |
# | 293  |                                                                                                                       It feels great to be the part of @IIITDelhi. https://t.co/IRRTtIpC6D                                                                                                                       | 24/07/2018 10:12:34 |     2      |       1       |         None        |
# | 294  |                                                                                                                  Thank you, @toonzratn for designing the logo of MIDAS. https://t.co/yx2u2Vs36Z                                                                                                                  | 24/07/2018 09:46:26 |     4      |       1       |          1          |
# | 295  |                                                                                                                We are on Facebook too. Like our page to get our updates. https://t.co/CRaw6KQPSf                                                                                                                 | 23/07/2018 16:25:05 |     3      |       1       |         None        |
# |      |                                                                                                                                                                                                                                                                                                                  |                     |            |               |                     |
# |      |                                                                  #MIDAS #IIITD #MultimediaResearch #NLP #ImageProcessing #DeepLearning #AI4HealthCare #Lipreading #FakeNewsDetection #CodeSwitchedLanguageProcessing #SocialMediaComputing #AI                                                                   |                     |            |               |                     |
# | 296  |                            MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information. MIDAS stands for Multimodal Digital Media Analysis Lab and it is founded by Dr. Rajiv Ratn Shah.                              | 23/07/2018 12:53:15 |     7      |       4       |         None        |
# |      |                                                                                                                                           URL: https://t.co/sPvbKgXKmg                                                                                                                                           |                     |            |               |                     |
# +------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+------------+---------------+---------------------+

# %% [markdown]
# # References

# %% [markdown]
# 1. Tweepy Documentation - http://docs.tweepy.org/en/3.7.0/index.html
# 2. Stack Overflow - https://stackoverflow.com/
